# %%
savedir = '/scratch/maf388/experiments/cifarbadgan1'

# %%
from IPython.display import Image, display
import glob, os

# %%
paths = sorted(glob.glob(savedir+'/*.png'),key=os.path.getmtime)
for pth in paths:
    display(Image(filename=pth))

# %%
print(paths[-1])
# Out:
# /scratch/maf388/experiments/cifarbadgan1/fake_samples_epoch_010.png
