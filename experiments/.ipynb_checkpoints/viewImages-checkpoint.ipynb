# %%
savedir = '/scratch/maf388/experiments/cifarbadgan'

# %%
from IPython.display import Image, display
import glob, os

# %%
paths = sorted(glob.glob(savedir+'/*.png'),key=os.path.getmtime)
for pth in paths:
    display(Image(filename=pth))

# %%
print(paths[-1])
# Out:
# /scratch/maf388/experiments/cifarbadgan/fake_samples_epoch_099.png
