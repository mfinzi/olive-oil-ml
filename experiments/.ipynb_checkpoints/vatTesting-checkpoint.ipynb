# %%
import torch, torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision.datasets import CIFAR10

from bgan.cnnTrainer import CnnTrainer
from bgan.vatCnnTrainer import VatCnnTrainer
from bgan.networkparts import layer13
import bgan.augLayers as augLayers
from bgan.schedules import cosLr, sigmoidConsRamp
import torch.optim as optim
import torch.nn as nn
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## CNN Configuration

# %%
savedir = '/home/maf388/tb-experiments/vatTesting/'

total_epochs = 1000
opt_constr = lambda params, base_lr: optim.SGD(params, base_lr, .9, weight_decay=1e-4, nesterov=True)
lr_lambda = cosLr(total_epochs, 1)

config = {'base_lr':.1, 'amntLab':4000, 
          'lab_BS':50, 'ul_BS':50, 'num_workers':0,
          'lr_lambda':lr_lambda, 'opt_constr':opt_constr,
          #'advEps':32, 'entMin':False, 
          }

baseCNN = layer13(numClasses=10)

fullCNN = nn.Sequential(
    augLayers.RandomTranslate(4),
    augLayers.RandomHorizontalFlip(),
    #augLayers.GaussianNoise(0.15),
    baseCNN,
)

# %% [markdown]
# ## Dataset

# %%
img_size = 32
transform_dev = transforms.Compose(
    [transforms.Resize(img_size),
     transforms.ToTensor(),
     transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])

transform_train = transform_dev
# transform_train = transforms.Compose(
#     [transforms.RandomCrop(32, padding=4),
#      transforms.RandomHorizontalFlip(),
#      transform_dev])

pathToDataset = '/scratch/datasets/cifar10/'
trainset = CIFAR10(pathToDataset, download=True, transform=transform_train)
devset = CIFAR10(pathToDataset, train=False, download=True, transform=transform_dev)
testset = None

datasets = (trainset, devset, testset)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
trainer = CnnTrainer(fullCNN,datasets,savedir,**config)

# %%
trainer.train(1000)
# Out:
# [  0/1000][     0/80000] Train_Acc(Batch): 0.060 Val_Acc: 0.100
# [ 25/1000][  2000/80000] Train_Acc(Batch): 0.680 Val_Acc: 0.627
# [ 50/1000][  4000/80000] Train_Acc(Batch): 0.860 Val_Acc: 0.728
# [ 75/1000][  6000/80000] Train_Acc(Batch): 0.960 Val_Acc: 0.740
# [100/1000][  8000/80000] Train_Acc(Batch): 0.980 Val_Acc: 0.721
# [125/1000][ 10000/80000] Train_Acc(Batch): 0.980 Val_Acc: 0.756
# [150/1000][ 12000/80000] Train_Acc(Batch): 1.000 Val_Acc: 0.773
# [175/1000][ 14000/80000] Train_Acc(Batch): 1.000 Val_Acc: 0.769
# [200/1000][ 16000/80000] Train_Acc(Batch): 0.980 Val_Acc: 0.755
# [225/1000][ 18000/80000] Train_Acc(Batch): 0.980 Val_Acc: 0.765
# [250/1000][ 20000/80000] Train_Acc(Batch): 1.000 Val_Acc: 0.775
# [275/1000][ 22000/80000] Train_Acc(Batch): 1.000 Val_Acc: 0.780
# [300/1000][ 24000/80000] Train_Acc(Batch): 1.000 Val_Acc: 0.755
# [325/1000][ 26000/80000] Train_Acc(Batch): 1.000 Val_Acc: 0.780
# [350/1000][ 28000/80000] Train_Acc(Batch): 0.980 Val_Acc: 0.753
# [375/1000][ 30000/80000] Train_Acc(Batch): 1.000 Val_Acc: 0.778
# [400/1000][ 32000/80000] Train_Acc(Batch): 1.000 Val_Acc: 0.791
# [425/1000][ 34000/80000] Train_Acc(Batch): 1.000 Val_Acc: 0.786
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d5e3698f69ab> in <module>()
# ----> 1 trainer.train(1000)
#
# ~/bayesganfuture/bgan/cnnTrainer.py in train(self, numEpochs)
#      60             self.lr_scheduler.step(epoch); self.epoch = epoch
#      61             for i in range(self.numBatchesPerEpoch):
# ---> 62                 trainData = to_var_gpu(next(self.train_iter))
#      63                 self.step(*trainData)
#      64                 self.logStuff(i, epoch, numEpochs, trainData)
#
# ~/bayesganfuture/bgan/utils.py in to_var_gpu(x, volatile)
#      11     if type(x) in [list, tuple]:
#      12         curry = lambda x: to_var_gpu(x, volatile)
# ---> 13         return type(x)(map(curry, x))
#      14     else:
#      15         return Variable(x, volatile=volatile).cuda()
#
# ~/bayesganfuture/bgan/utils.py in <lambda>(x)
#      10         return x
#      11     if type(x) in [list, tuple]:
# ---> 12         curry = lambda x: to_var_gpu(x, volatile)
#      13         return type(x)(map(curry, x))
#      14     else:
#
# ~/bayesganfuture/bgan/utils.py in to_var_gpu(x, volatile)
#      13         return type(x)(map(curry, x))
#      14     else:
# ---> 15         return Variable(x, volatile=volatile).cuda()
#      16
#      17 def to_lambda(x):
#
# ~/.conda/envs/env0/lib/python3.5/site-packages/torch/autograd/variable.py in cuda(self, device, async)
#     296
#     297     def cuda(self, device=None, async=False):
# --> 298         return CudaTransfer.apply(self, device, async)
#     299
#     300     def cpu(self):
#
# ~/.conda/envs/env0/lib/python3.5/site-packages/torch/autograd/_functions/tensor.py in forward(ctx, i, device, async)
#     199             return i.cuda(device, async=async)
#     200         else:
# --> 201             return i.cuda(async=async)
#     202
#     203     @staticmethod
#
# ~/.conda/envs/env0/lib/python3.5/site-packages/torch/_utils.py in _cuda(self, device, async)
#      67         else:
#      68             new_type = getattr(torch.cuda, self.__class__.__name__)
# ---> 69             return new_type(self.size()).copy_(self, async)
#      70
#      71
#
# KeyboardInterrupt:

# %%
trainer.getDevsetAccuracy()
# Out:
# 0.7746815286624203

# %%
trainer2 = VatCnnTrainer(fullCNN,datasets,savedir,**config)

# %%
from bgan.utils import to_var_gpu
_,(X,_) = to_var_gpu(next(trainer2.train_iter))

# %%
import matplotlib.pyplot as plt
import numpy as np
import torchvision.utils as vutils
def show(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1,2,0)), interpolation='nearest')
grid = vutils.make_grid(X.cpu().data,normalize=True,range=(-2.5,2.5))
show(grid)

# %%
from bgan.vatCnnTrainer import kl_div_withlogits, _l2_normalize, norm
from torch.autograd import Variable

eps = 32
adv = trainer2.getAdvPert(trainer2.CNN, X)
x_adv = X+eps*adv
rp = Variable(_l2_normalize(torch.randn(X.size())).cuda(),requires_grad=False)
x_rp = X+eps*rp
grid = vutils.make_grid(x_adv.cpu().data,normalize=True,range=(-2.5,2.5))
show(grid)

# %%
trainer2.CNN.train(False)

logits = trainer2.CNN(X)
logits_adv = trainer2.CNN(x_adv)
logits_rnd = trainer2.CNN(x_rp)
adv_kl = kl_div_withlogits(logits.detach(), logits_adv)
random_kl = kl_div_withlogits(logits.detach(), logits_rnd)
print("kls %.4E, %.4E"%(adv_kl,random_kl))
# Out:
# kls 8.6883E-01, 5.6879E-01
