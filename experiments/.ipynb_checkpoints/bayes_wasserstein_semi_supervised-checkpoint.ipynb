# %%
import numpy as np
import torch
import torchvision
import PIL.Image
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from skimage.transform import rescale

import torchvision.transforms as transforms


from bgan.datasets import make_semi_dataset_from_tensors, make_batch_generator, DatasetFromTensors
from bgan.synth_utils import js_div, kl_div, pca
from bgan.priors import FactorizedNormalPrior
import torch.nn.functional as F

from matplotlib import pyplot as plt
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
32/28
# Out:
# 1.1428571428571428

# %%
x_test.numpy().transpose((0, 2, 3, 1)).shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-43911b514b6e> in <module>()
# ----> 1 x_test.numpy().transpose((0, 2, 3, 1)).shape
#
# NameError: name 'x_test' is not defined

# %%
rescale(x_test.numpy().transpose((0, 2, 3, 1))[0], 32/28).shape

# %%
trainset

# %%
def rescale_images(img_arr, scale):
    new_imgs = []
    for img in img_arr:
        rescaled = rescale(image=img.transpose((1,2,0)), scale=scale)
        rescaled = rescaled.transpose((2, 0, 1))[None, :, :, :]
        new_imgs.append(rescaled)
    return np.vstack(new_imgs)

# %%
A = rescale_images(x_test.numpy()[:10], 32/28)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-14657111f9a6> in <module>()
# ----> 1 A = rescale_images(x_test.numpy()[:10], 32/28)
#
# NameError: name 'x_test' is not defined

# %%
x_train.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2132a220a582> in <module>()
# ----> 1 x_train.shape
#
# NameError: name 'x_train' is not defined

# %%
A.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d5a4efdcb733> in <module>()
# ----> 1 A.shape
#
# NameError: name 'A' is not defined

# %%
img_size = 32
transform = transforms.Compose(
    [transforms.Scale(img_size),transforms.ToTensor()])

trainset = torchvision.datasets.MNIST(root='./data', train=True,
                                        download=True, transform=transform)
testset = torchvision.datasets.MNIST(root='./data', train=False,
                                        download=True, transform=transform)
x_train, y_train = trainset.train_data[:, None, :, :].float() / 255, trainset.train_labels
x_test, y_test = testset.test_data[:, None, :, :].float() / 255, testset.test_labels

x_train = rescale_images(x_train.numpy(), 32/28)
x_test = rescale_images(x_test.numpy(), 32/28)
x_train = torch.from_numpy(x_train)
x_test = torch.from_numpy(x_test)
x_test = x_test.float()
y_test = y_test.numpy()

labeled, unlabeled = make_semi_dataset_from_tensors(x_train.float(), 
                                                    y_train[:, None], labeled_fraction=0.1)

# labeledloader = torch.utils.data.DataLoader(labeled, batch_size=50,
#                                           shuffle=True, num_workers=2)
# Out:
# /home/maf388/.conda/envs/env0/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
testset = DatasetFromTensors(x_test, y_test, labeled=True)

# %% [markdown]
# ## BGAN

# %%
def weight_init(m):
    if isinstance(m, nn.ConvTranspose2d) or isinstance(m, nn.Conv2d):
        m.weight.data.normal_(0.0, 0.02)
        m.bias.data.zero_()
        
def gen_weight_init(m):
    if isinstance(m, nn.ConvTranspose2d) or isinstance(m, nn.Conv2d):
        m.weight.data.normal_(0.0, 0.02)
        m.bias.data.zero_()
        
        
class GeneratorNetwork(nn.Module):
    # initializers
    def __init__(self, d=128, z_dim=100):
        super(GeneratorNetwork, self).__init__()
        self.init_net(d, z_dim)
        self.input_dim = z_dim
        
    def init_net(self, d, z_dim):
        self.deconv1 = nn.ConvTranspose2d(z_dim, d*4, 4, 1, 0)
        self.deconv1_bn = nn.BatchNorm2d(d*4)
        self.deconv2 = nn.ConvTranspose2d(d*4, d*2, 4, 2, 1)
        self.deconv2_bn = nn.BatchNorm2d(d*2)
        self.deconv3 = nn.ConvTranspose2d(d*2, d, 4, 2, 1)
        self.deconv3_bn = nn.BatchNorm2d(d)
        self.deconv4 = nn.ConvTranspose2d(d, 1, 4, 2, 1)

    # forward method
    def forward(self, x):
        x = x.view((-1, self.input_dim, 1, 1))
        x = F.relu(self.deconv1_bn(self.deconv1(x)))
        x = F.relu(self.deconv2_bn(self.deconv2(x)))
        x = F.relu(self.deconv3_bn(self.deconv3(x)))
        x = F.tanh(self.deconv4(x))

        return x
    

class DiscriminatorNetwork(nn.Module):
    
    def __init__(self, d=128, k=1):
        super(DiscriminatorNetwork, self).__init__()
        self.k = k
        self.init_net(d)
        
    
    # initializers
    def init_net(self, d):
        self.conv1 = nn.Conv2d(1, d, 4, 2, 1)
        self.conv2 = nn.Conv2d(d, d*2, 4, 2, 1)
        self.conv2_bn = nn.BatchNorm2d(d*2)
        self.conv3 = nn.Conv2d(d*2, d*4, 4, 2, 1)
        self.conv3_bn = nn.BatchNorm2d(d*4)
        self.conv4 = nn.Conv2d(d*4, self.k+1, 4, 1, 0)

    # forward method
    def forward(self, input):
        x = F.leaky_relu(self.conv1(input), 0.2)
        x = F.leaky_relu(self.conv2_bn(self.conv2(x)), 0.2)
        x = F.leaky_relu(self.conv3_bn(self.conv3(x)), 0.2)
        x = self.conv4(x)
        x = x.squeeze()
        return x

    def predict(self, input):
        return torch.max(self.forward(input.cuda())[:, 1:],1)[1]

# %%
gen = GeneratorNetwork()
disc = DiscriminatorNetwork(k=10)

z = Variable(torch.from_numpy(np.random.rand(10, 100)).float())
print(gen.forward(z).size())
print(disc(gen.forward(z)).size())
#disc.predict(gen.forward(z))
# Out:
# torch.Size([10, 1, 32, 32])
# torch.Size([10, 11])

# %%
from bgan.bgan_wasserstein import WBGAN

# %%
batch_size = 50
z_dim = 100

# %%
x_l.size()
# Out:
# torch.Size([50, 1, 32, 32])

# %%
# prior = UninformativePrior()
prior = FactorizedNormalPrior(std=10.)
gen = GeneratorNetwork()
disc = DiscriminatorNetwork()
# gen.apply(weight_init)
gen.apply(gen_weight_init)
disc.apply(weight_init)
bgan = WBGAN(gen, disc, prior, alpha=.9, eta=5e-5, disc_lr = 5e-5, gen_observed=20000, MAP=True, cuda=True)
samples = []
# Out:
# Moving generator and discriminator to GPU
# TODO: Weight Clipping constants?
# TODO: RMSProp?

# %%
for param in gen.parameters():
    print(param.size(), np.linalg.norm(param.cpu().data.numpy()))
# Out:
# torch.Size([100, 512, 4, 4]) 18.1333
# torch.Size([512]) 0.0
# torch.Size([512]) 12.9631
# torch.Size([512]) 0.0
# torch.Size([512, 256, 4, 4]) 28.9755
# torch.Size([256]) 0.0
# torch.Size([256]) 8.59386
# torch.Size([256]) 0.0
# torch.Size([256, 128, 4, 4]) 14.4764
# torch.Size([128]) 0.0
# torch.Size([128]) 6.81954
# torch.Size([128]) 0.0
# torch.Size([128, 1, 4, 4]) 0.902815
# torch.Size([1]) 0.0

# %% [markdown]
# ## Training

# %%
num_samples = 10

# %%
labeled_gen = make_batch_generator(labeled, 50)
unlabeled_gen = make_batch_generator(unlabeled, 50)

# %%
testloader = torch.utils.data.DataLoader(testset, batch_size=50,
            shuffle=True, num_workers=2)

# %%
def compute_accuracy():
    num_right = 0
    for batch in testloader:
        x, y = batch
        preds = bgan.discriminator.predict(Variable(x))
        num_right += np.sum(preds.cpu().data.numpy().reshape(-1) == y.numpy().reshape(-1))
    return num_right / len(testset)

compute_accuracy()
# Out:
# 0.098000000000000004

# %%
if isinstance(samples, np.ndarray):
    samples = [samples]
    
for i in range(20000):
    x_l, y_l = next(labeled_gen)
    x_u = next(unlabeled_gen)

    bgan.d_step(x_l,y_l,x_u)
    if not (i%5):
        bgan.g_step(x_l,y_l,x_u)

    if i%200 == 0:
        samples.append(bgan.sample(num_samples).cpu().data.numpy())
        acc = compute_accuracy()
        print(acc)
samples = np.vstack(samples)
# Out:
# 0.098
# 0.098
# 0.098
# Process Process-58:
# Process Process-57:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/maf388/.conda/envs/env0/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/home/maf388/.conda/envs/env0/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/home/maf388/.conda/envs/env0/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/maf388/.conda/envs/env0/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/maf388/.conda/envs/env0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/maf388/.conda/envs/env0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
# ...

# %%
imshow(torchvision.utils.make_grid(batch[:10]))

# %%
# samples_arr = np.array(samples[:-2])
# samples_ = samples[-2:]
# samples = [samples_arr]
# samples.append(samples_[0])
# samples.append(samples_[1])
# samples = np.vstack(samples)

# %%
# samples = bgan.sample(100).cpu().data.numpy()

# %%
# samples_arr = np.vstack(samples)
samples_arr = samples

# %%
samples_arr.shape
# Out:
# (1300, 1, 32, 32)

# %%
plt.imshow((samples_arr[-1, 0] + 1)/2, cmap='gray')

# %%
np.max(batch.numpy())
# Out:
# 1.0

# %%
samples_arr.shape
# Out:
# (1300, 1, 32, 32)

# %%
# np.save('samples/bwgan_mnist_samples.npy', samples_arr)

# %%
plt.figure(figsize=(20, 50))
show_epochs = [20, 30]
start, finish = show_epochs[0] * num_samples, (show_epochs[1]+1) * num_samples
# imshow(torchvision.utils.make_grid(torch.from_numpy(samples_arr[start:finish]), nrow=30))
imshow(torchvision.utils.make_grid(torch.from_numpy(samples_arr[:500]), nrow=10))
plt.axis('off')
# Out:
# (-0.5, 341.5, 1701.5, -0.5)
